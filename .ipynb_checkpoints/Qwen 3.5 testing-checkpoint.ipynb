# %%
# !pip install --upgrade transformers #pip install --upgrade transformers

# %%
from transformers import pipeline, set_seed, AutoTokenizer, AutoModelForCausalLM

# %%
import torch

# %%
model_id = "Qwen/Qwen3.5-4B"
tokenizer = AutoTokenizer.from_pretrained(model_id)
model = AutoModelForCausalLM.from_pretrained(model_id,device_map='cuda',dtype = torch.bfloat16)

# %%
pipe = pipeline(task='text-generation',model=model,tokenizer=tokenizer,return_full_text=False,temperature=0.5,top_k=20,top_p=0.95,max_new_tokens=300)

# %%
prompts
# Out:
# '<|im_start|>system\nYou are a helpful assistant.<|im_end|>\n<|im_start|>user\n[query]<|im_end|>\n<|im_start|>assistant\n<think>\n\n</think>\n\n'

# %%
query = 'who are you?'
def generate_text(query):
  messages = [
    {'role':'system', 'content':'You are a helpful assistant.'},
    {'role':'user', 'content':'[query]'}
]
  prompts = tokenizer.apply_chat_template(messages,tokenize=False,add_generation_prompt=True,enable_thinking=False)
  prompts = prompts.replace('[query]',query)
  with torch.no_grad():
    set_seed(42)
    return pipe(prompts)[0]['generated_text']

# %%
res = generate_text(query)

# %%
print(res)
# Out:
# I'm Qwen3.5, the latest large language model developed by Tongyi Lab. I'm designed to assist with a wide range of tasks, from answering questions and writing stories to coding, logical reasoning, and analyzing complex data. How can I help you?

# %%
tool_usage = """
{'calculation':'Used to calculate or to do any mathematical operations. It includes addition, substraction, multiplication, division. It also finds out square root and square of a number.'
'search':'it is used to search external website when internal information is not sufficient or model does not have information.',
'from_sql':'Extract the data from sql'}
"""
system_prompt=f"""
You are a helpful assistant who is excellent at tool calling. Your task is to identify which tools need to be used.
You will be provided with along with thier usage.
{tool_usage}
provide your response in json format.
"""

# %%
def generate_text(query,system_prompt):
  messages = [
    {'role':'system', 'content':system_prompt},
    {'role':'user', 'content':'[query]'}
]
  prompts = tokenizer.apply_chat_template(messages,tokenize=False,add_generation_prompt=True,enable_thinking=False)
  prompts = prompts.replace('[query]',query)
  with torch.no_grad():
    set_seed(42)
    return pipe(prompts)[0]['generated_text']

# %%
query="what is the weather for new delhi today?"
res=generate_text(query,system_prompt)
res

# %%
print(res)
# Out:
# {
#   "tool": "search",
#   "description": "Search external websites to find the current weather in New Delhi."
# }

# %%
query="i need to calculate 2+3."
res=generate_text(query,system_prompt)
print(res)

# %% [markdown]
# output: </br>
# {
#   "tool": "calculation",
#   "arguments": {
#     "operation": "addition",
#     "operands": [2, 3]
#   }
# }

# %% [markdown]
# ### Test pandas

# %%
import pandas as pd

# %%
df = pd.read_excel('call_center_data.xlsx')
df.head()
# Out:
#              ID      Customer Name      Sentiment  CSAT Score Call Timestamp  \
# 0  PIS-39858047  Frances Gullefant        Neutral           8     2024-01-01
# 1  ROH-40287216  Harcourt Zoanetti       Negative           5     2024-01-01
# 2  NKC-39578431  Washington Oxteby       Negative           3     2024-01-02
# 3  APY-17008648       Rafe Duffitt  Very Negative           4     2024-01-02
# 4  MHK-38443501          Tris Bent       Positive           8     2024-01-02
#
#              Reason        City          State      Channel Response Time  \
# 0  Billing Question  Charleston  West Virginia      Chatbot    Within SLA
# 1  Billing Question    Honolulu         Hawaii  Call-Center    Within SLA
# 2  Billing Question      Dallas          Texas      Chatbot    Within SLA
# 3  Billing Question  Fort Myers        Florida        Email     Below SLA
# 4  Billing Question  Tuscaloosa        Alabama          Web    Within SLA
#
#    Call Duration (Minutes)     Call Center
# 0                       14      Chicago/IL
# 1                       32  Los Angeles/CA
# 2                        6       Denver/CO
# 3                       26  Los Angeles/CA
# 4                       26  Los Angeles/CA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70 entries, 0 to 69
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       70 non-null     object
#  1   Customer Name            70 non-null     object
#  2   Sentiment                70 non-null     object
#  3   CSAT Score               70 non-null     int64
#  4   Call Timestamp           70 non-null     datetime64[ns]
#  5   Reason                   70 non-null     object
#  6   City                     70 non-null     object
#  7   State                    70 non-null     object
#  8   Channel                  70 non-null     object
#  9   Response Time            70 non-null     object
#  10  Call Duration (Minutes)  70 non-null     int64
#  11  Call Center              70 non-null     object
# dtypes: datetime64[ns](1), int64(2), object(9)
# memory usage: 6.7+ KB

# %%
information = """
<class 'pandas.core.frame.DataFrame'>
RangeIndex: 70 entries, 0 to 69
Data columns (total 12 columns):
 #   Column                   Non-Null Count  Dtype
---  ------                   --------------  -----
 0   ID                       70 non-null     object
 1   Customer Name            70 non-null     object
 2   Sentiment                70 non-null     object
 3   CSAT Score               70 non-null     int64
 4   Call Timestamp           70 non-null     datetime64[ns]
 5   Reason                   70 non-null     object
 6   City                     70 non-null     object
 7   State                    70 non-null     object
 8   Channel                  70 non-null     object
 9   Response Time            70 non-null     object
 10  Call Duration (Minutes)  70 non-null     int64
 11  Call Center              70 non-null     object
dtypes: datetime64[ns](1), int64(2), object(9)
memory usage: 6.7+ KB
"""
columns = """
['ID', 'Customer Name', 'Sentiment', 'CSAT Score', 'Call Timestamp',
       'Reason', 'City', 'State', 'Channel', 'Response Time',
       'Call Duration (Minutes)', 'Call Center']
"""
head = """
ID	Customer Name	Sentiment	CSAT Score	Call Timestamp	Reason	City	State	Channel	Response Time	Call Duration (Minutes)	Call Center
0	PIS-39858047	Frances Gullefant	Neutral	8	2024-01-01	Billing Question	Charleston	West Virginia	Chatbot	Within SLA	14	Chicago/IL
1	ROH-40287216	Harcourt Zoanetti	Negative	5	2024-01-01	Billing Question	Honolulu	Hawaii	Call-Center	Within SLA	32	Los Angeles/CA
2	NKC-39578431	Washington Oxteby	Negative	3	2024-01-02	Billing Question	Dallas	Texas	Chatbot	Within SLA	6	Denver/CO
"""

# %%
system_prompt=f""" You are an AI assistant who is excellent at writing python pandas code. Based on user query, write the pandas code.
you will be provided with columns and informations for that dataframe.
Here are columns for the dataset - {columns} and informations related to dataset - {information} and top 3 rows of the dataset - {head}.
Return only pandas code.
"""

# %%
def generate_text(query,system_prompt=system_prompt):
  messages = [
    {'role':'system', 'content':system_prompt},
    {'role':'user', 'content':'[query]'}
]
  prompts = tokenizer.apply_chat_template(messages,tokenize=False,add_generation_prompt=True,enable_thinking=False)
  prompts = prompts.replace('[query]',query)
  with torch.no_grad():
    set_seed(42)
    return pipe(prompts)[0]['generated_text']

# %%
query = "Find out sentiments for the call center located in 'Los Angeles/CA' along with the counts of sentiment in descending order."
res =generate_text(query)
print(res)
# Out:
# Both `max_new_tokens` (=300) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# ```python
# # Filter the dataframe for the 'Los Angeles/CA' call center
# la_df = df[df['Call Center'] == 'Los Angeles/CA']
#
# # Group by 'Sentiment' and count occurrences
# sentiment_counts = la_df.groupby('Sentiment').size()
#
# # Sort the counts in descending order
# sentiment_counts_sorted = sentiment_counts.sort_values(ascending=False)
#
# # Display the result
# print(sentiment_counts_sorted)
# ```

# %% [markdown]
# outputs: </br>
# ```python
# # Filter the dataframe for the 'Los Angeles/CA' call center
# la_df = df[df['Call Center'] == 'Los Angeles/CA']
#
# # Group by 'Sentiment' and count occurrences
# sentiment_counts = la_df.groupby('Sentiment').size()
#
# # Sort the counts in descending order
# sentiment_counts_sorted = sentiment_counts.sort_values(ascending=False)
#
# # Display the result
# print(sentiment_counts_sorted)
# ```

# %%
exec(res.replace('```python','').replace("```",""))
# Out:
# Sentiment
# Negative         11
# Positive          6
# Very Positive     6
# Very Negative     5
# Neutral           2
# dtype: int64

# %%
df[df['Call Center']=='Los Angeles/CA']['Sentiment'].value_counts().sort_values(ascending=False)
# Out:
# Sentiment
# Negative         11
# Positive          6
# Very Positive     6
# Very Negative     5
# Neutral           2
# Name: count, dtype: int64

# %%
query = "Draw a pie chart based on sentiments for the call center located in 'Los Angeles/CA' along with the counts of sentiment."
res =generate_text(query)
print(res)
# Out:
# Both `max_new_tokens` (=300) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# ```python
# import pandas as pd
# import matplotlib.pyplot as plt
#
# # Assuming 'df' is the DataFrame variable containing the data
# df_los_angeles = df[df['Call Center'] == 'Los Angeles/CA']
#
# # Count sentiments for the selected call center
# sentiment_counts = df_los_angeles['Sentiment'].value_counts()
#
# # Create the pie chart
# plt.figure(figsize=(8, 6))
# plt.pie(sentiment_counts, labels=sentiment_counts.index, autopct='%1.1f%%', startangle=140)
# plt.title('Sentiment Distribution for Call Center: Los Angeles/CA')
# plt.axis('equal')  # Equal aspect ratio ensures the pie chart is circular
# plt.show()
# ```

# %%
exec(res.replace('```python','').replace("```",""))

# %%
query = "show me sentiments distribution for the first 10 days."
res =generate_text(query)
print(res)
# Out:
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# Both `max_new_tokens` (=300) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# ```python
# import pandas as pd
#
# # Assuming the dataframe is named 'df'
# # Filter for the first 10 days based on 'Call Timestamp'
# df_first_10_days = df[df['Call Timestamp'] <= pd.Timestamp('2024-01-10')]
#
# # Calculate sentiments distribution
# sentiment_distribution = df_first_10_days['Sentiment'].value_counts()
#
# # Display the result
# print(sentiment_distribution)
# ```

# %%
exec(res.replace('```python','').replace("```",""))
# Out:
# Sentiment
# Negative         11
# Very Negative     4
# Neutral           3
# Positive          3
# Very Positive     2
# Name: count, dtype: int64

# %%
df_first_10_days = df[df['Call Timestamp'] <= pd.Timestamp('2024-01-10')]

# Calculate sentiments distribution
sentiment_distribution = df_first_10_days['Sentiment'].value_counts()

# Display the result
print(sentiment_distribution)
# Out:
# Sentiment
# Negative         11
# Very Negative     4
# Neutral           3
# Positive          3
# Very Positive     2
# Name: count, dtype: int64

# %%
df_first_10_days
# Out:
#               ID       Customer Name      Sentiment  CSAT Score  \
# 0   PIS-39858047   Frances Gullefant        Neutral           8
# 1   ROH-40287216   Harcourt Zoanetti       Negative           5
# 2   NKC-39578431   Washington Oxteby       Negative           3
# 3   APY-17008648        Rafe Duffitt  Very Negative           4
# 4   MHK-38443501           Tris Bent       Positive           8
# 5   QKL-49133006        Kassie Elman  Very Negative           4
# 6   ZPZ-31710059    Elbertina Hewins  Very Positive          10
# 7   IJF-13083880      Garland Chuney       Negative           3
# 8   ZKW-68562847   Caroljean Bischop       Negative           3
# 9   NIL-47926257      Delmor McKleod       Negative           6
# 10  BPQ-80812775       Julee O'Gavin       Negative           3
# 11  ZOK-34480332        Jaye Gribbon        Neutral           7
# 12  ZMB-79323804    Brodie Dobrowski       Negative           5
# 13  YYO-56445305       Sibylla Kemet  Very Negative           2
# 14  JYD-67455825  Quintilla Hourston       Negative           6
# 15  KNO-93249512       Maggi Simpson       Positive           9
# 16  VFG-63863025      Early Andrassy  Very Positive           9
# 17  UCT-41608771         Ettie Ruoff  Very Negative           3
# 18  YLF-83918836       Bogey McReath       Positive           7
# 19  QCH-83950486  Sephira Philippart       Negative           3
# 20  PDB-14404239    Charles Sandison        Neutral           5
# 21  LFZ-17229282         Zora Keelin       Negative           3
# 22  VKV-67119644     Lillis Dewhurst       Negative           4
#
#    Call Timestamp            Reason           City                 State  \
# 0      2024-01-01  Billing Question     Charleston         West Virginia
# 1      2024-01-01  Billing Question       Honolulu                Hawaii
# 2      2024-01-02  Billing Question         Dallas                 Texas
# 3      2024-01-02  Billing Question     Fort Myers               Florida
# 4      2024-01-02  Billing Question     Tuscaloosa               Alabama
# 5      2024-01-03  Billing Question     Charleston        South Carolina
# 6      2024-01-03          Payments      Pensacola               Florida
# 7      2024-01-04  Billing Question    Little Rock              Arkansas
# 8      2024-01-04  Billing Question      Nashville             Tennessee
# 9      2024-01-05  Billing Question        El Paso                 Texas
# 10     2024-01-05  Billing Question      Santa Ana            California
# 11     2024-01-06  Billing Question     Huntington         West Virginia
# 12     2024-01-06  Billing Question     Pittsburgh          Pennsylvania
# 13     2024-01-07  Billing Question         Tucson               Arizona
# 14     2024-01-07          Payments     Des Moines                  Iowa
# 15     2024-01-08          Payments  San Francisco            California
# 16     2024-01-08  Billing Question        Lansing              Michigan
# 17     2024-01-08  Billing Question     Washington  District of Columbia
# 18     2024-01-08  Billing Question  New York City              New York
# 19     2024-01-09  Billing Question        Madison             Wisconsin
# 20     2024-01-09  Billing Question    Fort Pierce               Florida
# 21     2024-01-10  Billing Question        Lubbock                 Texas
# 22     2024-01-10  Billing Question       Stockton            California
#
#         Channel Response Time  Call Duration (Minutes)     Call Center
# 0       Chatbot    Within SLA                       14      Chicago/IL
# 1   Call-Center    Within SLA                       32  Los Angeles/CA
# 2       Chatbot    Within SLA                        6       Denver/CO
# 3         Email     Below SLA                       26  Los Angeles/CA
# 4           Web    Within SLA                       26  Los Angeles/CA
# 5           Web    Within SLA                        6    Baltimore/MD
# 6   Call-Center    Within SLA                        9  Los Angeles/CA
# 7   Call-Center    Within SLA                       15    Baltimore/MD
# 8           Web    Within SLA                       12  Los Angeles/CA
# 9           Web    Within SLA                       42  Los Angeles/CA
# 10      Chatbot     Above SLA                       44    Baltimore/MD
# 11      Chatbot    Within SLA                       29    Baltimore/MD
# 12      Chatbot    Within SLA                       35    Baltimore/MD
# 13          Web    Within SLA                       30  Los Angeles/CA
# 14  Call-Center    Within SLA                       29  Los Angeles/CA
# 15  Call-Center    Within SLA                        9    Baltimore/MD
# 16      Chatbot    Within SLA                        8  Los Angeles/CA
# 17      Chatbot     Above SLA                       35      Chicago/IL
# 18          Web    Within SLA                       20    Baltimore/MD
# 19          Web    Within SLA                       31  Los Angeles/CA
# 20        Email     Below SLA                       39  Los Angeles/CA
# 21  Call-Center    Within SLA                       38       Denver/CO
# 22  Call-Center     Above SLA                       44       Denver/CO

# %%
df.head(10)
# Out:
#              ID      Customer Name      Sentiment  CSAT Score Call Timestamp  \
# 0  PIS-39858047  Frances Gullefant        Neutral           8     2024-01-01
# 1  ROH-40287216  Harcourt Zoanetti       Negative           5     2024-01-01
# 2  NKC-39578431  Washington Oxteby       Negative           3     2024-01-02
# 3  APY-17008648       Rafe Duffitt  Very Negative           4     2024-01-02
# 4  MHK-38443501          Tris Bent       Positive           8     2024-01-02
# 5  QKL-49133006       Kassie Elman  Very Negative           4     2024-01-03
# 6  ZPZ-31710059   Elbertina Hewins  Very Positive          10     2024-01-03
# 7  IJF-13083880     Garland Chuney       Negative           3     2024-01-04
# 8  ZKW-68562847  Caroljean Bischop       Negative           3     2024-01-04
# 9  NIL-47926257     Delmor McKleod       Negative           6     2024-01-05
#
#              Reason         City           State      Channel Response Time  \
# 0  Billing Question   Charleston   West Virginia      Chatbot    Within SLA
# 1  Billing Question     Honolulu          Hawaii  Call-Center    Within SLA
# 2  Billing Question       Dallas           Texas      Chatbot    Within SLA
# 3  Billing Question   Fort Myers         Florida        Email     Below SLA
# 4  Billing Question   Tuscaloosa         Alabama          Web    Within SLA
# 5  Billing Question   Charleston  South Carolina          Web    Within SLA
# 6          Payments    Pensacola         Florida  Call-Center    Within SLA
# 7  Billing Question  Little Rock        Arkansas  Call-Center    Within SLA
# 8  Billing Question    Nashville       Tennessee          Web    Within SLA
# 9  Billing Question      El Paso           Texas          Web    Within SLA
#
#    Call Duration (Minutes)     Call Center
# 0                       14      Chicago/IL
# 1                       32  Los Angeles/CA
# 2                        6       Denver/CO
# 3                       26  Los Angeles/CA
# 4                       26  Los Angeles/CA
# 5                        6    Baltimore/MD
# 6                        9  Los Angeles/CA
# 7                       15    Baltimore/MD
# 8                       12  Los Angeles/CA
# 9                       42  Los Angeles/CA
